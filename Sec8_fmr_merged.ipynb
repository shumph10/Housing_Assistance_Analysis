# %%
import pandas as pd

# %%
fmr = pd.read_csv('/Users/user/Desktop/trying/fmr_done_rearranged.csv')
sec8 = pd.read_csv('/Users/user/Desktop/trying/Sec8_done_rearranged.csv')

# %%
sec8_fmr = pd.merge(sec8, fmr, 
                   on='_id', 
                   how='inner')
  
# displaying result
print(sec8_fmr)
# Out:
#                cbsasub         _id      state_name State_Alpha  \
# 0     METRO33860M33860   100199999         Alabama          AL
# 1     METRO19300M19300   100399999         Alabama          AL
# 2     NCNTY01005N01005   100599999         Alabama          AL
# 3     METRO13820M13820   100799999         Alabama          AL
# 4     METRO13820M13820   100999999         Alabama          AL
# ...                ...         ...             ...         ...
# 4751  METRO41980MM7440  7215199999     Puerto Rico          PR
# 4752  METRO49500M49500  7215399999     Puerto Rico          PR
# 4753  NCNTY78010N78010  7801099999  Virgin Islands          VI
# 4754  NCNTY78020N78020  7802099999  Virgin Islands          VI
# 4755  NCNTY78030N78030  7803099999  Virgin Islands          VI
#
#                                Metro_Area_Name   county_town_name  \
# 0                           Montgomery, AL MSA     Autauga County
# 1                Daphne-Fairhope-Foley, AL MSA     Baldwin County
# ...

# %%
sec8_fmr.head()
# Out:
#             cbsasub        _id state_name State_Alpha  \
# 0  METRO33860M33860  100199999    Alabama          AL
# 1  METRO19300M19300  100399999    Alabama          AL
# 2  NCNTY01005N01005  100599999    Alabama          AL
# 3  METRO13820M13820  100799999    Alabama          AL
# 4  METRO13820M13820  100999999    Alabama          AL
#
#                             Metro_Area_Name county_town_name     County_Name  \
# 0                        Montgomery, AL MSA   Autauga County  Autauga County
# 1             Daphne-Fairhope-Foley, AL MSA   Baldwin County  Baldwin County
# 2                        Barbour County, AL   Barbour County  Barbour County
# 3  Birmingham-Hoover, AL HUD Metro FMR Area      Bibb County     Bibb County
# 4  Birmingham-Hoover, AL HUD Metro FMR Area    Blount County   Blount County
#
#    state  county  metro_x  ...  fmr2_17  fmr3_17  fmr4_17  fmr_0_22  fmr_1_22  \
# 0      1       1        1  ...      822     1054     1425       643       764
# ...

# %%
print(sec8_fmr.columns)
# Out:
# Index(['cbsasub', '_id', 'state_name', 'State_Alpha', 'Metro_Area_Name',
#        'county_town_name', 'County_Name', 'state', 'county', 'metro_x',
#        'median2017', 'l50_2_17', 'ELI_2_17', 'l80_2_17', 'median2022',
#        'l50_2_22', 'ELI_2_22', 'l80_2_22', 'fmr0_17', 'fmr1_17', 'fmr2_17',
#        'fmr3_17', 'fmr4_17', 'fmr_0_22', 'fmr_1_22', 'fmr_2_22', 'fmr_3_22',
#        'fmr_4_22', 'metro_code', 'metro_y'],
#       dtype='object')

# %%
yup = sec8_fmr.drop(['cbsasub','metro_x'], axis=1)

# %%
yup.head()
# Out:
#          _id state_name State_Alpha                           Metro_Area_Name  \
# 0  100199999    Alabama          AL                        Montgomery, AL MSA
# 1  100399999    Alabama          AL             Daphne-Fairhope-Foley, AL MSA
# 2  100599999    Alabama          AL                        Barbour County, AL
# 3  100799999    Alabama          AL  Birmingham-Hoover, AL HUD Metro FMR Area
# 4  100999999    Alabama          AL  Birmingham-Hoover, AL HUD Metro FMR Area
#
#   county_town_name     County_Name  state  county  median2017  l50_2_17  ...  \
# 0   Autauga County  Autauga County      1       1       59700     23900  ...
# 1   Baldwin County  Baldwin County      1       3       61500     24600  ...
# 2   Barbour County  Barbour County      1       5       46100     18450  ...
# 3      Bibb County     Bibb County      1       7       63100     25250  ...
# 4    Blount County   Blount County      1       9       63100     25250  ...
#
# ...

# %%
print(yup.columns)
# Out:
# Index(['_id', 'state_name', 'State_Alpha', 'Metro_Area_Name',
#        'county_town_name', 'County_Name', 'state', 'county', 'median2017',
#        'l50_2_17', 'ELI_2_17', 'l80_2_17', 'median2022', 'l50_2_22',
#        'ELI_2_22', 'l80_2_22', 'fmr0_17', 'fmr1_17', 'fmr2_17', 'fmr3_17',
#        'fmr4_17', 'fmr_0_22', 'fmr_1_22', 'fmr_2_22', 'fmr_3_22', 'fmr_4_22',
#        'metro_code', 'metro'],
#       dtype='object')

# %%
yup.columns= ['_id', 'state_name', 'State_Alpha', 'Metro_Area_Name',
       'county_town_name', 'County_Name', 'state', 'county', 'median2017',
       'l50_2_17', 'ELI_2_17', 'l80_2_17', 'median2022', 'l50_2_22',
       'ELI_2_22', 'l80_2_22', 'fmr0_17', 'fmr1_17', 'fmr2_17', 'fmr3_17',
       'fmr4_17', 'fmr_0_22', 'fmr_1_22', 'fmr_2_22', 'fmr_3_22', 'fmr_4_22',
       'metro_code', 'metro']

# %%
# yup.to_csv("Sec8_fmr_done",index=False)
